# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
coord = [[1,0], [3,0], [4, np.sqrt(3)], [3, np.sqrt(3)*2], [1, np.sqrt(3)*2], [0, np.sqrt(3)]]
coord.append(coord[0]) #repeat the first point to create a 'closed loop'

xs, ys = zip(*coord) #create lists of x and y values

plt.figure()
plt.plot(xs,ys) 

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import numpy as np

# %%
plt.axes()

# circle = plt.Circle((0, 0), radius=0.75, fc='y')
# plt.gca().add_patch(circle)


points = [[1,0], [3,0], [4, np.sqrt(3)], [3, np.sqrt(3)*2], [1, np.sqrt(3)*2], [0, np.sqrt(3)]]
line = plt.Polygon(points, edgecolor='r')
plt.gca().add_patch(line)


Path = mpath.Path


# pp1 = mpatches.PathPatch(
#     Path([(3.5, np.sqrt(3)/2), (2, np.sqrt(3)), (2, 0), (3.5, np.sqrt(3)/2)],
#          [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.CLOSEPOLY]),
#     fc="none", transform=ax.transData)

pp1 = mpatches.PathPatch(
    Path([(2,0), (2, np.sqrt(3)), (3.5, np.sqrt(3)/2), (2, 0)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.CLOSEPOLY]),
    fc="none", transform=ax.transData)

plt.gca().add_patch(pp1)

plt.axis('scaled')
plt.show()

# %%
set_aspect
